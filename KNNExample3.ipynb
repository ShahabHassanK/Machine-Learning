# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing, model_selection, neighbors
import math, pickle

# %%
df = pd.read_csv('customer_purchase_data.csv')
df
# Out:
#       Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0      40       1   66120.267939                  8                0
# 1      20       1   23579.773583                  4                2
# 2      27       1  127821.306432                 11                2
# 3      24       1  137798.623120                 19                3
# 4      31       1   99300.964220                 19                1
# ...   ...     ...            ...                ...              ...
# 1495   39       1   65048.141834                 13                0
# 1496   67       1   28775.331069                 18                2
# 1497   40       1   57363.247541                  7                4
# 1498   63       0  134021.775532                 16                2
# 1499   50       0   52625.665974                 13                0
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# ...

# %%
x = np.array(df.drop('PurchaseStatus', axis=1))
y = np.array(df['PurchaseStatus'])

# %%
x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y, test_size = 0.4)
clf = neighbors.KNeighborsClassifier()
clf.fit(x_train, y_train)
with open('KNN3.pickle', 'wb') as file:
    pickle.dump(clf,file)
pickle_in = open('KNN3.pickle', 'rb')
clf = pickle.load(pickle_in)
accuracy = clf.score(x_test, y_test)
accuracy
# Out:
# 0.5683333333333334

# %%
example_test = np.array([[20,0,12150.75,3,1,12.7068,1,1], [40,1,66200.670,8,0,31.568601,0,5], [40,1,76200.670,11,2,35.568601,1,5]])
example_test = example_test.reshape(len(example_test),-1)
predictions = clf.predict(example_test)
predictions
# Out:
# array([0, 0, 0], dtype=int64)
